# %%
import pandas as pd

# %%
#read the dataset
data = pd.read_csv("creditcard.csv")

#look at the first 5 rows
print(data.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#count fraud and normal
print(data["Class"].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
(data["Class"].value_counts(normalize=True) * 100)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
fraud_rows = data[data["Class"] == 1]
print(fraud_rows.head())
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
normal_rows = data[data["Class"] == 0]
print(normal_rows.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
fraud_rows.shape
# Out:
# (492, 31)

# %%
normal_rows.shape
# Out:
# (284315, 31)

# %%
average_amt = data.groupby("Class")["Amount"].mean()
average_amt
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %%
normal_rows["Amount"].hist(bins=60)
# Out:
# <Axes: >

# %%
fraud_rows["Amount"].hist(bins=60)
# Out:
# <Axes: >

# %%
normal_rows["Time"].hist(bins=60)
# Out:
# <Axes: >

# %%
fraud_rows["Time"].hist(bins=60)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
#take the big table and remove the class column, keep only the features column
X = data.drop("Class", axis=1)
#only the class column
Y = data["Class"]

# %%
X.shape
# Out:
# (284807, 30)

# %%
Y.shape
# Out:
# (284807,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((227845, 30), (56962, 30), (227845,), (56962,))

# %%
y_train.value_counts()
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Class
# 0    56864
# 1       98
# Name: count, dtype: int64

# %%
train_data = X_train.copy()
train_data["Class"] = y_train

# %%
train_fraud = train_data[train_data["Class"] == 1]
train_normal = train_data[train_data["Class"] == 0]

# %%
train_normal_under = train_normal.sample(n=len(train_fraud), random_state=42)

# %%
train_balanced = pd.concat([train_fraud, train_normal_under])

# %%
X_train_bal = train_balanced.drop("Class", axis=1)
y_train_bal = train_balanced["Class"]

# %%
y_train_bal.value_counts()
# Out:
# Class
# 1    394
# 0    394
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
model = Pipeline([("scaler", StandardScaler()), ("lr", LogisticRegression(max_iter=1000))])

# %%
model.fit(X_train_bal, y_train_bal)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('lr', LogisticRegression(max_iter=1000))])

# %%
#y_pred = model.predict(X_test)

# %%
y_proba = model.predict_proba(X_test)

fraud_probs = y_proba[:, 1]

# %%
import matplotlib.pyplot as plt

plt.hist(fraud_probs[y_test == 0], bins=50, alpha=0.5, label="Normal")
plt.hist(fraud_probs[y_test == 1], bins=50, alpha=0.5, label="Fraud")
plt.legend()
plt.title("Fraud Probability Distribution")
plt.show()

# %%
def evaluate_triage(probs, y_true, t_review=0.2, t_block=0.95):
    allow_mask = probs < t_review
    review_mask = (probs >= t_review) & (probs < t_block)
    block_mask = probs >= t_block

    print("ALLOW:", allow_mask.sum())
    print("REVIEW:", review_mask.sum())
    print("BLOCK:", block_mask.sum())

    fraud_caught = ((review_mask | block_mask) & (y_true == 1)).sum()
    total_fraud = (y_true == 1).sum()
    print("Fraud caught by REVIEW+BLOCK:", fraud_caught, "/", total_fraud)

    innocent_blocked = (block_mask & (y_true == 0)).sum()
    print("Innocent blocked:", innocent_blocked)

# %%
evaluate_triage(fraud_probs, y_test, t_review=0.2, t_block=0.99)
# Out:
# ALLOW: 50831
# REVIEW: 5953
# BLOCK: 178
# Fraud caught by REVIEW+BLOCK: 91 / 98
# Innocent blocked: 102

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=200, max_depth=None, random_state=42, n_jobs=-1)

# %%
rf_model.fit(X_train_bal, y_train_bal)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %%
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
evaluate_triage(rf_probs, y_test, t_review=0.2, t_block=0.99)
# Out:
# ALLOW: 46305
# REVIEW: 10574
# BLOCK: 83
# Fraud caught by REVIEW+BLOCK: 94 / 98
# Innocent blocked: 17

# %%
import pandas as pd

feature_importance = pd.Series(
    rf_model.feature_importances_,
    index=X_train_bal.columns
).sort_values(ascending=False)

feature_importance.head(10)
# Out:
# V14    0.200396
# V10    0.112489
# V4     0.110598
# V12    0.092604
# V17    0.086918
# V3     0.059447
# V16    0.047449
# V11    0.042683
# V7     0.032991
# V2     0.032200
# dtype: float64

# %%
t_review = 0.2
t_block = 0.99

block_mask = rf_probs >= t_block
review_mask = (rf_probs >= t_review) & (rf_probs < t_block)
allow_mask = rf_probs < t_review

# %%
blocked_indices = y_test.index[block_mask]
blocked_indices[:5]
# Out:
# Index([190263, 77348, 102442, 14920, 119781], dtype='int64')

# %%
X_test.loc[blocked_indices[0]]
# Out:
# Time      128759.000000
# V1            -1.272117
# V2             1.827615
# V3            -3.810610
# V4             0.583759
# V5            -0.641242
# V6            -1.389043
# V7            -1.954054
# V8             1.173920
# V9            -2.053191
# V10           -3.345061
# V11            2.376404
# V12           -2.538052
# V13           -0.090454
# V14           -2.426168
# V15           -1.618648
# V16           -3.515944
# V17           -6.199008
# V18           -2.410606
# V19            0.760435
# V20           -0.027268
# V21            0.858998
# V22            0.858775
# V23            0.083079
# V24            0.741676
# V25           -0.173234
# V26            0.534870
# V27            0.183562
# V28            0.020316
# Amount         0.760000
# Name: 190263, dtype: float64

# %%
normal_indices = y_test[y_test == 0].index
normal_indices[:10]
# Out:
# Index([263020, 11378, 147283, 219439, 36939, 243438, 259448, 43800, 66742,
#        66499],
#       dtype='int64')

# %%
review_indices = y_test.index[
    (rf_probs >= 0.2) & (rf_probs < 0.99)
]
review_indices[:10]
# Out:
# Index([147283, 36939, 83371, 12890, 224464, 188175, 278912, 198694, 187592,
#        185764],
#       dtype='int64')

# %%
def fraud_decision(model, X_row, t_review=0.2, t_block=0.99):
    prob = model.predict_proba(X_row)[0, 1]

    if prob >= t_block:
        decision = "BLOCK"
    elif prob >= t_review:
        decision = "REVIEW"
    else:
        decision = "ALLOW"

    return prob, decision

# %%
idx = blocked_indices[0]
X_one = X_test.loc[[idx]]  # keep as DataFrame

prob, decision = fraud_decision(rf_model, X_one)

print("Fraud probability:", prob)
print("Decision:", decision)
# Out:
# Fraud probability: 0.995
# Decision: BLOCK

# %%
import joblib

joblib.dump(rf_model, "rf_fraud_model.joblib")
joblib.dump(list(X_train_bal.columns), "feature_columns.joblib")
# Out:
# ['feature_columns.joblib']

# %%
app_code = """
import streamlit as st
import joblib
import pandas as pd
import numpy as np

# Load model + columns (must be in same folder as app.py)
rf_model = joblib.load("rf_fraud_model.joblib")
feature_columns = joblib.load("feature_columns.joblib")

def show_decision(decision: str):
    if decision == "ALLOW":
        st.success("Decision: ALLOW ✅")
    elif decision == "REVIEW":
        st.warning("Decision: REVIEW 👀")
    else:
        st.error("Decision: BLOCK ⛔")


st.set_page_config(page_title="Fraud Detection", layout="centered")
st.title("Fraud Detection – Triage System")
st.info("Model: Random Forest | Policy: t_review=0.20 (send to human review), t_block=0.99 (auto-block).")
st.write("Random Forest fraud detection with ALLOW / REVIEW / BLOCK decisions.")

# Threshold sliders (your final policy defaults)
t_review = st.slider("Review threshold (t_review)", 0.0, 1.0, 0.2, 0.01)
t_block = st.slider("Block threshold (t_block)", 0.0, 1.0, 0.99, 0.01)

if t_review >= t_block:
    st.error("t_review must be less than t_block")
    st.stop()

st.divider()

# ✅ Evidence: show the performance you achieved
st.subheader("Offline Results (Test Set)")
st.write("- Fraud caught by REVIEW+BLOCK: **94 / 98**")
st.write("- Innocent auto-blocked: **17**")
st.write("- Outputs: **ALLOW / REVIEW / BLOCK**")

st.divider()

st.subheader("Model Insight (Global Feature Importance)")
st.caption("Top features the model relies on when detecting fraud.")
importances = pd.Series(rf_model.feature_importances_, index=feature_columns).sort_values(ascending=False)
st.dataframe(importances.head(10))

# We'll use these for simple local explanation
top_features = list(importances.head(5).index)

st.divider()

# Optional: demo mode (pick a row from X_test if available)
st.subheader("Demo Mode")
st.caption("Pick a transaction index from X_test.csv to test quickly.")

demo_available = False
try:
    X_test = pd.read_csv("X_test.csv", index_col=0)
    y_test = pd.read_csv("y_test.csv", index_col=0).iloc[:, 0]
    demo_available = True
except Exception:
    demo_available = False

if demo_available:
    idx = st.number_input("Transaction index (row id)", value=int(X_test.index[0]), step=1)

    if idx in X_test.index:
        X_one = X_test.loc[[idx]][feature_columns]

        if st.button("Predict (Demo)"):
            prob = rf_model.predict_proba(X_one)[0, 1]
            decision = "BLOCK" if prob >= t_block else ("REVIEW" if prob >= t_review else "ALLOW")

            st.metric("Fraud probability", f"{prob:.3f}")
            show_decision(decision)
            st.write(f"True label (demo): {int(y_test.loc[idx])}  (1=Fraud, 0=Normal)")

            # ✅ Simple local explanation: show top-risk signals for this row
            st.subheader("Local Signals (Top Features)")
            st.caption("These are the most influential features globally, shown for this specific transaction.")
            st.dataframe(X_one[top_features].T.rename(columns={X_one.index[0]: "value"}))

    else:
        st.warning("That index is not in X_test.csv. Try another.")
else:
    st.info("Demo mode not available yet. (Create X_test.csv and y_test.csv to enable it.)")

st.divider()

# Manual input mode
st.subheader("Manual Input (All Features)")
st.caption("Enter feature values manually if you don't have demo CSVs.")

input_data = {}
for col in feature_columns:
    input_data[col] = st.number_input(col, value=0.0)

X_manual = pd.DataFrame([input_data], columns=feature_columns)

if st.button("Predict (Manual)"):
    prob = rf_model.predict_proba(X_manual)[0, 1]
    decision = "BLOCK" if prob >= t_block else ("REVIEW" if prob >= t_review else "ALLOW")

    st.metric("Fraud probability", f"{prob:.3f}")
    show_decision(decision)

    # ✅ Simple local explanation for manual input too
    st.subheader("Local Signals (Top Features)")
    st.caption("These are the most influential features globally, shown for your input.")
    st.dataframe(X_manual[top_features].T.rename(columns={0: "value"}))

st.divider()

# ✅ Responsible AI note
st.caption(
    "Note: This is a decision-support demo. 'BLOCK' is reserved for very high-confidence cases. "
    "Uncertain cases are routed to 'REVIEW' to reduce harm to legitimate users."
)
"""

with open("app.py", "w") as f:
    f.write(app_code)

print("✅ app.py written successfully")
# Out:
# ✅ app.py written successfully

# %%
X_test.to_csv("X_test.csv", index=True)
y_test.to_csv("y_test.csv", index=True)
print("✅ X_test.csv and y_test.csv saved")
# Out:
# ✅ X_test.csv and y_test.csv saved
